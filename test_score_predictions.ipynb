# %%
#import the data
import pandas as pd

# %%
df = pd.read_csv('/Users/Janzen/Documents/test_scores.csv')

# %%
#view data
df.head(20)
# Out:
#    school school_setting school_type classroom teaching_method  n_student  \
# 0   ANKYI          Urban  Non-public       6OL        Standard       20.0
# 1   ANKYI          Urban  Non-public       6OL        Standard       20.0
# 2   ANKYI          Urban  Non-public       6OL        Standard       20.0
# 3   ANKYI          Urban  Non-public       6OL        Standard       20.0
# 4   ANKYI          Urban  Non-public       6OL        Standard       20.0
# 5   ANKYI          Urban  Non-public       6OL        Standard       20.0
# 6   ANKYI          Urban  Non-public       6OL        Standard       20.0
# 7   ANKYI          Urban  Non-public       6OL        Standard       20.0
# 8   ANKYI          Urban  Non-public       6OL        Standard       20.0
# 9   ANKYI          Urban  Non-public       6OL        Standard       20.0
# 10  ANKYI          Urban  Non-public       6OL        Standard       20.0
# 11  ANKYI          Urban  Non-public       6OL        Standard       20.0
# ...

# %%
#number of instances
df.shape[0]
# Out:
# 2133

# %%
#remove any whitespace from column names to avoid any Key Errors
df.columns = df.columns.str.strip()

# %%
#remove seemingly irrelevant columns
df.drop(['student_id','classroom'], axis=1, inplace=True)

# %%
#describe data
df.describe()
# Out:
#          n_student      pretest     posttest
# count  2133.000000  2133.000000  2133.000000
# mean     22.796531    54.955931    67.102203
# std       4.228893    13.563101    13.986789
# min      14.000000    22.000000    32.000000
# 25%      20.000000    44.000000    56.000000
# 50%      22.000000    56.000000    68.000000
# 75%      27.000000    65.000000    77.000000
# max      31.000000    93.000000   100.000000

# %%
#determine how many unique values are in certain columns
df['school_setting'].value_counts().count()
# Out:
# 3

# %%
df['school_type'].value_counts().count()
# Out:
# 2

# %%
df['school'].value_counts().count()
# Out:
# 23

# %%
#how many public and non-public schools
df['school_type'].value_counts()
# Out:
# Public        1582
# Non-public     551
# Name: school_type, dtype: int64

# %%
#how many schools are urban, rural, or suburban
df['school_setting'].value_counts()
# Out:
# Urban       906
# Suburban    717
# Rural       510
# Name: school_setting, dtype: int64

# %%
#get mean by school setting (urban, rural, suburban)
school_settings_grouped = df.groupby(['school_setting']).mean()
school_settings_grouped
# Out:
#                 n_student    pretest   posttest
# school_setting
# Rural           20.015686  51.490196  64.050980
# Suburban        21.683403  63.841004  76.037657
# Urban           25.242826  49.875276  61.748344

# %%
#get mean by school
schools_grouped = df.groupby(['school']).mean()
schools_grouped
# Out:
#         n_student    pretest   posttest
# school
# ANKYI   20.512195  61.341463  71.390244
# CCAAW   18.412844  64.623853  78.110092
# CIMBB   18.648649  65.067568  76.945946
# CUQAM   26.850467  53.925234  65.560748
# DNQDD   24.934426  54.327869  66.565574
# FBUMG   15.565217  62.891304  78.608696
# GJJHK   23.932203  53.194915  65.025424
# GOKXL   21.468750  50.796875  64.953125
# GOOBU   26.569620  38.196203  49.613924
# IDGFP   19.063830  75.202128  87.223404
# KFZMY   26.038462  41.865385  54.576923
# KZKKE   22.279279  37.261261  47.918919
# LAYPA   19.140351  62.035088  73.508772
# OJOBU   20.530864  56.197531  67.814815
# QOQTS   25.080537  52.597315  64.671141
# UAGPU   21.781609  62.390805  71.873563
# UKPGS   21.593750  78.453125  91.164062
# UUUQX   16.976190  67.309524  79.261905
# VHDHF   17.274510  52.666667  66.843137
# VKWQH   20.100000  52.060000  64.820000
# VVTVA   28.649123  36.008772  49.175439
# ZMNYA   23.028986  68.130435  81.608696
# ...

# %%
schools_grouped.max()
# Out:
# 91.1640625

# %%
schools_grouped.min()
# Out:
# 47.91891891891892
